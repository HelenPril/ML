# %%
import requests

import urllib.request
import json

# %%
import pandas as pd

from sklearn.metrics import roc_auc_score,roc_curve

from urllib import request, parse


import dill
dill._dill._reverse_typemap['ClassType'] = type

from sklearn.model_selection import train_test_split

# %%
# !pip install flask-ngrok

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, jsonify

# %%
app = Flask(__name__)
run_with_ngrok(app)  # Start ngrok when app is run

@app.route("/a")
def hello():
    return "Hello World!"

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://1ad6-35-239-234-118.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [05/Dec/2021 13:19:17] "GET /a HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Dec/2021 13:19:18] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/GeekBrains/'

# %%
with open(path + 'boost_pipeline.dill', 'rb') as in_strm:
    model = dill.load(in_strm)

# %%
data = pd.read_csv(path +"data_banknote_authentication.txt", header=None)

data = data.rename(columns={0:'0', 1:'1', 2:'2', 3:'3', 4:'4'})

from sklearn.model_selection import train_test_split

x_data = data.iloc[:,:-1]
y_data = data.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=7)

# %%
# Обработчики и запуск Flask
app = Flask(__name__)
run_with_ngrok(app)  # Start ngrok when app is run

@app.route('/predict', methods=['GET', 'POST'])
def predict():
  data = {"success": False}
  # ensure an image was properly uploaded to our endpoint
  if request.method == "POST":
      first, second, third = "", "", "qq"
      request_json = request.get_json()
  if request_json["0"]:
      first = request_json['0']
  
  if request_json["1"]:
      second = request_json['1']
		       
  if request_json["2"]:
      third = request_json['2']
   
  preds = model.predict_proba(pd.DataFrame({"0": [first],
                                            "1": [second],
                                            "2": [third]}))

  data["predictions"] = preds[:, 1][0]
	
  data["success"] = True

	# return the data dictionary as a JSON response
  return jsonify(data)


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://326b-35-239-234-118.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040

# %%
response = send_json(x_test[['0', '1', '2']])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-23-e47d74cfbc24> in <module>()
# ----> 1 response = send_json(x_test[['0', '1', '2']])
#
# <ipython-input-18-cc644e7239d7> in send_json(x)
#       8     headers = {'content-type': 'application/json; charset=utf-8'}
#       9     response = requests.post(myurl, json=body, headers=headers)
# ---> 10     return response.json()['predictions']
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
# ...

# %%
x_test[['0', '1', '2']].head()
# Out:
#           0        1       2
# 263  4.9880   7.2052 -3.2846
# 313  2.1274   5.1939 -1.7971
# 318  1.5799  -4.7076  7.9186
# 915 -1.7490  -6.3320  6.0987
# 13  -1.5768  10.8430  2.5462
